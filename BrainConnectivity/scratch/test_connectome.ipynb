# %% [markdown]
# # Test Connectome
#
# 2025-12-05
# The goal of this script is to determine if the current connectome generation is consistent with a reference pipeline.
# Mehta, K., Salo, T., Madison, T. J., Adebimpe, A., Bassett, D. S., Bertolero, M., … & Satterthwaite, T. D. (2024). XCP-D: A Robust Pipeline for the post-processing of fMRI data. Imaging Neuroscience, 2, 1-26. doi:10.1162/imag_a_00257.

# %%
data = pd.read_pickle("..\data\harmonize_data.pkl")
data.sample(2)
